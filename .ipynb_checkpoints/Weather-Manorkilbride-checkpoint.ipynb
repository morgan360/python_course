# %% [markdown]
# BLESSINGTON (HEMPSTOWN) 53.192,-6.503 Station Num = 8623

# %%
import os
import wget-6.503

# %%
def download(url: str, file: str):
    """
    Download file from <url>

    :param url: URL to file
    :param file: Local file path
    """
    if not os.path.isfile(file):
        print('Downloading ' + file + '...')
        wget.download(url, file)
        print('Download Finished')

# %%
download('http://cli.fusio.net/cli/climate_data/webdata/dly8623.csv', '/Users/morgan/Downloads')

# %%
# import the list of stations
import pandas as pd
df = pd.read_csv("/Users/morgan/Documents/Courses/Python/MyModules/StationDetails.csv")
print(df)
# Out:
#        County  Station Number                       name  Height (m)  Easting  \
# 0        Cork            5704                 AHERLAMORE         122   150000
# 1        Cork            1203              ALLIHIES G.S.          58    58700
# 2        Cork             306               ARAGLEN G.S.          94   192700
# 3        Cork            5006         ARAGLEN TROUT FARM          91   190800
# 4        Cork            6806      ARAGLEN TROUT FARM II          73   190500
# ...       ...             ...                        ...         ...      ...
# 1935  Donegal            1343  SPEENOGE (GRIANAN ESTATE)           5   235800
# 1936  Donegal             442      STRANORLAR (VOC.SCH.)          21   214500
# 1937  Donegal            1242     STRANORLAR-Cavan_Lower          27   217525
# 1938  Donegal            1143           TERMON (GOLDRUM)         152   212285
# 1939  Donegal            5237                     finner          45   184200
#
# ...

# %%
# The shape attribute gives rows and colulms. Note shape is an attribute. (note I deleted first line of csv)
df.shape

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1940 entries, 0 to 1939
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   County          1940 non-null   object
#  1   Station Number  1940 non-null   int64
#  2   name            1940 non-null   object
#  3   Height (m)      1940 non-null   int64
#  4   Easting         1940 non-null   int64
#  5   Northing        1940 non-null   int64
#  6   Latitude        1940 non-null   float64
#  7   Longitude       1940 non-null   float64
#  8   Open Year       1940 non-null   int64
#  9   Close Year      1420 non-null   float64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 151.7+ KB

# %%
#stops truncating rows
pd.options.display.max_rows = 4000

# %%
# df.head(10)
df.tail(100)
# Out:
#        County  Station Number                             name  Height (m)  \
# 1840  Donegal             142                      CONVOY G.S.          49
# 1841  Donegal            1644           CREESLOUGH (ARDS ROAD)           8
# 1842  Donegal             844              CREESLOUGH-Brockagh         119
# 1843  Donegal             944       CREESLOUGH_(Carrownamaddy)          88
# 1844  Donegal            1641            CROLLY_(Filter-Works)          91
# 1845  Donegal            1941              DERRYHENNY DOOCHARY          57
# 1846  Donegal             440        DONEGAL (CULLIONBOY W.W.)          94
# 1847  Donegal             540             DONEGAL (DIST.HOSP.)          17
# 1848  Donegal             941               DOOCHARY (CUMMEEN)          56
# 1849  Donegal            1542                DRUMKEEN(LEGLAND)         128
# 1850  Donegal             144        DUNFANAGHY (ST.PATRICK,S)           9
# ...

# %%
# Setting max rows and columns
pd.set_option('display.max_columns', 10)
pd.set_option('display.max_rows', 85)

# %%
df

# %%
df.head(90)

# %% [markdown]
# ## What is a dataframe?

# %%
# single person
person = {
    "first": "Corey", 
    "last": "Schafer", 
    "email": "CoreyMSchafer@gmail.com"
}

# %%
# Data for many people use list
people = {
    "first": ["Corey"], 
    "last": ["Schafer"], 
    "email": ["CoreyMSchafer@gmail.com"]
}

# %%
# Data for many people use list
people = {
    "first": ["Corey", 'Jane', 'John'], 
    "last": ["Schafer", 'Doe', 'Doe'], 
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
# Find the second person keys are coloums and lists are rows (two dimminision)

# %%
# access a colulm
people['email']
# Out:
# ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com']

# %%
import pandas as pd
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
# index added by pandas

# %%
# Access a single colulm
df['email']
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# 2          JohnDoe@email.com
# Name: email, dtype: object

# %% [markdown]
# ## Series
# A series is a single dimension array. (A colulm). A Dataframe is a container for multiple series.

# %%
# Dot notation
df.email
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# 2          JohnDoe@email.com
# Name: email, dtype: object

# %% [markdown]
# **Note:** can get mixed up using dot notation, therefore use dot notation. eg. a colum could be called count ann method.

# %%
# note a list within the brackets

df[['last','email']]
# Out:
#       last                    email
# 0  Schafer  CoreyMSchafer@gmail.com
# 1      Doe        JaneDoe@email.com
# 2      Doe        JohnDoe@email.com

# %%
df.['last','email']
# Out:
#   File "<ipython-input-27-28bb849a42fd>", line 1
#     df.['last','email']
#        ^
# SyntaxError: invalid syntax

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
# rows by iloc and loc (i stands for index)
df.iloc[0:2]
# Out:
#    first
# 0  Corey
# 1   Jane

# %%
# rows and coluumns
df.iloc[0:2,0:1]
# Out:
#    first
# 0  Corey
# 1   Jane

# %%
# loc search by lable: the lables are indices at the moment but see later (index with lables)
df.loc[1]
# Out:
# first                 Jane
# last                   Doe
# email    JaneDoe@email.com
# Name: 1, dtype: object

# %%
df.loc[0:1]
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com

# %%
df.loc[0:2,'email']
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# 2          JohnDoe@email.com
# Name: email, dtype: object

# %%
# 
df.loc[0:2,['email','last']]
# Out:
#                      email     last
# 0  CoreyMSchafer@gmail.com  Schafer
# 1        JaneDoe@email.com      Doe
# 2        JohnDoe@email.com      Doe
