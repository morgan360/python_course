# %% [markdown]
# # Property Prices in Dublin

# %%
# Import
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
sns.set(style="darkgrid")

# %%
df = pd.read_csv('../data/dublin_house_prices.csv')

# %%
df.shape
# Out:
# (9853, 10)

# %%
df.head()
# Out:
#     _id                 Date                                        Address  \
# 0  2025  2019-02-21T00:00:00         APT 8, THE GARDEN HOUSE, WATERFALL AVE
# 1  4513  2019-04-16T00:00:00         49 AILESBURY RD, BALLSBRIDGE, DUBLIN 4
# 2  9575  2019-08-01T00:00:00   Block 1 and Block 2, Belleville, Castleknock
# 3  5013  2019-04-29T00:00:00  THE GREY GABLES, 34A GILFORD ROAD, SANDYMOUNT
# 4  4182  2019-04-10T00:00:00                 29 TEMPLE RD, DARTRY, DUBLIN 6
#
#   Postal_Code  County          Price Not Full Market Price VAT Exclusive  \
# 0    Dublin 3  Dublin  €6,750,000.00                    No            No
# 1    Dublin 4  Dublin  €6,750,000.00                    No            No
# 2    Dublin 7  Dublin  €5,791,178.00                    No            No
# 3         NaN  Dublin  €5,425,000.00                    No            No
# 4    Dublin 6  Dublin  €4,800,000.00                    No            No
#
#                  Description of Property Property Size Description
# 0  Second-Hand Dwelling house /Apartment                       NaN
# 1  Second-Hand Dwelling house /Apartment                       NaN
# 2  Second-Hand Dwelling house /Apartment                       NaN
# 3  Second-Hand Dwelling house /Apartment                       NaN
# 4  Second-Hand Dwelling house /Apartment                       NaN

# %%
df.dtypes
# Out:
# _id                           int64
# Date                         object
# Address                      object
# Postal_Code                  object
# County                       object
# Price                        object
# Not Full Market Price        object
# VAT Exclusive                object
# Description of Property      object
# Property Size Description    object
# dtype: object

# %%
df.head()
# Out:
#     _id                 Date                                        Address  \
# 0  2025  2019-02-21T00:00:00         APT 8, THE GARDEN HOUSE, WATERFALL AVE
# 1  4513  2019-04-16T00:00:00         49 AILESBURY RD, BALLSBRIDGE, DUBLIN 4
# 2  9575  2019-08-01T00:00:00   Block 1 and Block 2, Belleville, Castleknock
# 3  5013  2019-04-29T00:00:00  THE GREY GABLES, 34A GILFORD ROAD, SANDYMOUNT
# 4  4182  2019-04-10T00:00:00                 29 TEMPLE RD, DARTRY, DUBLIN 6
#
#   Postal_Code  County          Price Not Full Market Price VAT Exclusive  \
# 0    Dublin 3  Dublin  €6,750,000.00                    No            No
# 1    Dublin 4  Dublin  €6,750,000.00                    No            No
# 2    Dublin 7  Dublin  €5,791,178.00                    No            No
# 3         NaN  Dublin  €5,425,000.00                    No            No
# 4    Dublin 6  Dublin  €4,800,000.00                    No            No
#
#                  Description of Property Property Size Description
# 0  Second-Hand Dwelling house /Apartment                       NaN
# 1  Second-Hand Dwelling house /Apartment                       NaN
# 2  Second-Hand Dwelling house /Apartment                       NaN
# 3  Second-Hand Dwelling house /Apartment                       NaN
# 4  Second-Hand Dwelling house /Apartment                       NaN

# %%
df["Postal_Code"].value_counts()
# Out:
# Dublin 15    847
# Dublin 24    573
# Dublin 18    487
# Dublin 11    402
# Dublin 9     398
# Dublin 8     376
# Dublin 7     373
# Dublin 13    361
# Dublin 12    330
# Dublin 4     323
# Dublin 16    298
# Dublin 5     278
# Dublin 14    261
# Dublin 3     258
# Dublin 6     247
# Dublin 22    225
# Dublin 1     160
# Dublin 2      97
# Dublin 10     80
# Dublin 20     67
# Dublin 17     60
# Dublin 6w     18
# Name: Postal_Code, dtype: int64

# %%
num_price = df['Price'].replace( '[\€,) ]+','',regex=True ).replace( '[(]','-',     regex=True ).replace( '', 'NaN',     regex=True ).astype(float) 
df['num_price'] = num_price

# %%
df
# Out:
#        _id                 Date  \
# 0     2025  2019-02-21T00:00:00
# 1     4513  2019-04-16T00:00:00
# 2     9575  2019-08-01T00:00:00
# 3     5013  2019-04-29T00:00:00
# 4     4182  2019-04-10T00:00:00
# ...    ...                  ...
# 9848  2324  2019-02-27T00:00:00
# 9849   469  2019-01-18T00:00:00
# 9850  1519  2019-02-12T00:00:00
# 9851  3493  2019-03-27T00:00:00
# 9852  6168  2019-05-24T00:00:00
#
#                                             Address Postal_Code  County  \
# 0            APT 8, THE GARDEN HOUSE, WATERFALL AVE    Dublin 3  Dublin
# 1            49 AILESBURY RD, BALLSBRIDGE, DUBLIN 4    Dublin 4  Dublin
# 2      Block 1 and Block 2, Belleville, Castleknock    Dublin 7  Dublin
# 3     THE GREY GABLES, 34A GILFORD ROAD, SANDYMOUNT         NaN  Dublin
# 4                    29 TEMPLE RD, DARTRY, DUBLIN 6    Dublin 6  Dublin
# ...                                             ...         ...     ...
# 9848         65 WHITECHURCH WAY, BALLYBODEN, DUBLIN   Dublin 16  Dublin
# 9849        4 CAMBRIDGE TERRACE, RANELAGH, DUBLIN 6    Dublin 6  Dublin
# 9850            67 GRANGE PARK RD, RAHENY, DUBLIN 5    Dublin 5  Dublin
# 9851      20 WATERSIDE GROVE, SWORDS ROAD, MALAHIDE         NaN  Dublin
# 9852          3 ARBOUR HILL, STONEYBATTER, DUBLIN 7    Dublin 7  Dublin
#
#               Price Not Full Market Price VAT Exclusive  \
# 0     €6,750,000.00                    No            No
# 1     €6,750,000.00                    No            No
# 2     €5,791,178.00                    No            No
# 3     €5,425,000.00                    No            No
# 4     €4,800,000.00                    No            No
# ...             ...                   ...           ...
# 9848     €12,463.22                   Yes            No
# 9849     €10,000.00                    No            No
# 9850      €8,000.00                    No            No
# 9851      €8,000.00                    No            No
# 9852      €5,900.00                    No            No
#
#                     Description of Property Property Size Description  \
# 0     Second-Hand Dwelling house /Apartment                       NaN
# 1     Second-Hand Dwelling house /Apartment                       NaN
# 2     Second-Hand Dwelling house /Apartment                       NaN
# 3     Second-Hand Dwelling house /Apartment                       NaN
# 4     Second-Hand Dwelling house /Apartment                       NaN
# ...                                     ...                       ...
# 9848  Second-Hand Dwelling house /Apartment                       NaN
# 9849  Second-Hand Dwelling house /Apartment                       NaN
# 9850  Second-Hand Dwelling house /Apartment                       NaN
# 9851  Second-Hand Dwelling house /Apartment                       NaN
# 9852  Second-Hand Dwelling house /Apartment                       NaN
#
#        num_price
# 0     6750000.00
# 1     6750000.00
# 2     5791178.00
# 3     5425000.00
# 4     4800000.00
# ...          ...
# 9848    12463.22
# 9849    10000.00
# 9850     8000.00
# 9851     8000.00
# 9852     5900.00
#
# [9853 rows x 11 columns]

# %%
df['Price'] = df['Price'].replace( '[\€,) ]+','',regex=True ).replace( '[(]','-',     regex=True ).replace( '', 'NaN',     regex=True ).astype(float) 
df.describe()
# Out:
#                _id         Price     num_price
# count  9853.000000  9.853000e+03  9.853000e+03
# mean   4933.777834  4.160314e+05  4.160314e+05
# std    2850.024868  3.256552e+05  3.256552e+05
# min       1.000000  5.900000e+03  5.900000e+03
# 25%    2465.000000  2.650000e+05  2.650000e+05
# 50%    4935.000000  3.380000e+05  3.380000e+05
# 75%    7400.000000  4.581490e+05  4.581490e+05
# max    9880.000000  6.750000e+06  6.750000e+06

# %%
df.describe()
# Out:
#                _id         Price     num_price
# count  9853.000000  9.853000e+03  9.853000e+03
# mean   4933.777834  4.160314e+05  4.160314e+05
# std    2850.024868  3.256552e+05  3.256552e+05
# min       1.000000  5.900000e+03  5.900000e+03
# 25%    2465.000000  2.650000e+05  2.650000e+05
# 50%    4935.000000  3.380000e+05  3.380000e+05
# 75%    7400.000000  4.581490e+05  4.581490e+05
# max    9880.000000  6.750000e+06  6.750000e+06

# %%
df.boxplot(column=['num_price'], return_type='axes',figsize=(15,15))

# show plot 
plt.show()

# %%
plt.figure(figsize=(12,100))
sns.boxplot( x=df["num_price"], y=df["Postal_Code"], palette="Blues", width=0.3)

# %%
filt = (df['Postal_Code']=='Dublin 1')

# %%
df[filt]
# Out:
#        _id                 Date  \
# 7     4083  2019-04-08T00:00:00
# 45    3665  2019-03-29T00:00:00
# 519   4449  2019-04-15T00:00:00
# 604   5108  2019-05-01T00:00:00
# 759   8223  2019-07-03T00:00:00
# ...    ...                  ...
# 9557  4393  2019-04-12T00:00:00
# 9621  4524  2019-04-16T00:00:00
# 9695  3855  2019-04-02T00:00:00
# 9744  4698  2019-04-18T00:00:00
# 9775  7780  2019-06-26T00:00:00
#
#                                                 Address Postal_Code  County  \
# 7     5 SPENCER HOUSE, CUSTOM HOUSE SQ, MAYOR ST LOW...    Dublin 1  Dublin
# 45                    24A 25 25A, HILL STREET, DUBLIN 1    Dublin 1  Dublin
# 519                            41 BOLTON STREET, DUBLIN    Dublin 1  Dublin
# 604                  12 NORTH RICHMOND STREET, DUBLIN 1    Dublin 1  Dublin
# 759                       APT 1, 30 BOLTON ST, DUBLIN 1    Dublin 1  Dublin
# ...                                                 ...         ...     ...
# 9557                   78A SUMMERHILL, DUBLIN 1, DUBLIN    Dublin 1  Dublin
# 9621           7 HENRIETTA HALL, HENRIETTA ST, DUBLIN 1    Dublin 1  Dublin
# 9695  APT 14 BLOCK D THE ATRIUM, THE STEELWORKS, FOL...    Dublin 1  Dublin
# 9744                   45, FERRYMANS CROSSING, DUBLIN 1    Dublin 1  Dublin
# 9775                   15 RUTLAND PLACE NORTH, DUBLIN 1    Dublin 1  Dublin
#
#           Price Not Full Market Price VAT Exclusive  \
# 7     4064100.0                    No            No
# 45    2407000.0                    No            No
# 519    840000.0                    No            No
# 604    800000.0                    No            No
# 759    750000.0                    No            No
# ...         ...                   ...           ...
# 9557   150000.0                    No            No
# 9621   140000.0                    No            No
# 9695   120000.0                    No            No
# 9744    99000.0                   Yes            No
# 9775    75000.0                    No            No
#
#                     Description of Property Property Size Description  \
# 7     Second-Hand Dwelling house /Apartment                       NaN
# 45    Second-Hand Dwelling house /Apartment                       NaN
# 519   Second-Hand Dwelling house /Apartment                       NaN
# 604   Second-Hand Dwelling house /Apartment                       NaN
# 759   Second-Hand Dwelling house /Apartment                       NaN
# ...                                     ...                       ...
# 9557  Second-Hand Dwelling house /Apartment                       NaN
# 9621  Second-Hand Dwelling house /Apartment                       NaN
# 9695  Second-Hand Dwelling house /Apartment                       NaN
# 9744  Second-Hand Dwelling house /Apartment                       NaN
# 9775  Second-Hand Dwelling house /Apartment                       NaN
#
#       num_price
# 7     4064100.0
# 45    2407000.0
# 519    840000.0
# 604    800000.0
# 759    750000.0
# ...         ...
# 9557   150000.0
# 9621   140000.0
# 9695   120000.0
# 9744    99000.0
# 9775    75000.0
#
# [160 rows x 11 columns]

# %%
filt = ((df['Postal_Code']=='Dublin 8') | (df['Postal_Code']=='Dublin 6')) & (df['num_price'] <= 3000000)
df1 = df.loc[filt, ['Postal_Code', 'Price','num_price']]

# %%
df1
# Out:
#      Postal_Code      Price  num_price
# 30      Dublin 6  2675000.0  2675000.0
# 31      Dublin 6  2667800.0  2667800.0
# 33      Dublin 6  2650000.0  2650000.0
# 34      Dublin 6  2625000.0  2625000.0
# 43      Dublin 6  2425000.0  2425000.0
# ...          ...        ...        ...
# 9810    Dublin 8    45000.0    45000.0
# 9811    Dublin 8    43500.0    43500.0
# 9833    Dublin 8    20000.0    20000.0
# 9840    Dublin 8    15000.0    15000.0
# 9849    Dublin 6    10000.0    10000.0
#
# [619 rows x 3 columns]

# %%
df1
df1.boxplot(column='num_price',by='Postal_Code', figsize=(15,15))

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(8,10))
sns.boxplot( y=df1["num_price"] )
plt.title("Dublin 8")
plt.ylabel("House Prices Euro") 
plt.tight_layout()
plt.show()

# %%
df1.boxplot(column='num_price',by='Postal_Code', figsize=(15,15))

# %%
plt.figure(figsize=(8,10))
sns.boxplot( x=df1["Postal_Code"], y=df1["num_price"], palette="Blues", width=0.3)

# %%
import matplotlib.ticker as ticker
plt.figure(figsize=(15,10))

ax=sns.boxplot( x=df1["num_price"], y=df1["Postal_Code"], palette="Blues", width=0.3)
ax.xaxis.set_major_locator(ticker.MultipleLocator(500000))
ax.xaxis.set_major_formatter(ticker.ScalarFormatter())
#set_style("ticks", {"xtick.major.size": 8, "ytick.major.size": 8})

# %%
# Size in Inches
a4_dims = (11.7, 8.27)

#plt.figure(figsize=(15,10))

# Cut the window in 2 parts
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True,figsize=a4_dims, gridspec_kw={"height_ratios": (.15, .85)})
 
# Add a graph in each part
x= sns.boxplot(df1["num_price"], ax=ax_box)
sns.distplot(df1["num_price"], ax=ax_hist)

# Remove x axis name for the boxplot
ax_box.set(xlabel='')
# Out:
# [Text(0.5, 0, '')]

# %%
ax.figure.savefig('file.png')
