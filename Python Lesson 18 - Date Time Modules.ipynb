# %% [markdown]
# version 1.1

# %% [markdown]
# # Date Time Module

# %% [markdown]
# Date types **niave** and **aware** dates. Niave dates do not care about time zones and daylight saving, so they are easier to work with.

# %%
import datetime

x = datetime.datetime.now()
print(x)
# Out:
# 2020-11-12 21:19:37.297991

# %% [markdown]
# <hr>
#
# **Explaination** <br/>
# The date contains year, month, day, hour, minute, second, and microsecond.
# The datetime module has many methods to return information about the date object.
#
# <hr>

# %%
import datetime

x = datetime.datetime.now()

print(x.year)

# The strftime() method can output the date and time in many formats
print(x.strftime("%a"))
# Out:
# 2020
# Thu

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# There are many methods available in the datetime library.
tday = datetime.date.today()
print(tday)
print(tday.day)
print(tday.weekday())
print(tday.isoweekday())
# Out:
# 2020-11-12
# 12
# 3
# 4

# %% [markdown]
# ## SAQ 1 - What day is today?
# Output today's date in the following formats:<br>
# d1 = 12/11/2020 <br>
# d2 = November 12, 2020 <br>
# d3 = 11/12/20<br>
# d4 = Nov-12-2020<br>

# %%
# Put your code here
from datetime import date

today = date.today()

# dd/mm/YY
d1 = today.strftime("%d/%m/%Y")
print("d1 =", d1)

# Textual month, day and year	
d2 = today.strftime("%B %d, %Y")
print("d2 =", d2)

# mm/dd/y
d3 = today.strftime("%m/%d/%y")
print("d3 =", d3)

# Month abbreviation, day and year	
d4 = today.strftime("%b-%d-%Y")
print("d4 =", d4)

# %% [markdown]
# ## Creat datetime objects

# %%
#Get the current date
today = datetime.date.today()
print(today)

# %%
from datetime import datetime

# datetime object containing current date and time
now = datetime.now()
 
print("now =", now)

# dd/mm/YY H:M:S
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
print("date and time =", dt_string)
# Out:
# now = 2020-11-12 21:29:33.282273
# date and time = 12/11/2020 21:29:33

# %%
# Create a date object
dat_1 = datetime(2007, 12, 31)
print(dat_1)
# Out:
# 2007-12-31 00:00:00

# %%
# Create a date object
dat_2 = datetime(1997, 12, 31)
print(dat_2)
# Out:
# 1997-12-31 00:00:00

# %%
print(dat_1 - dat_2)
# Out:
# 3652 days, 0:00:00

# %% [markdown]
# ## strptime()
# The strptime() method creates a datetime object from the given string.
# **Note:** You cannot create datetime object from every string. The string needs to be in a certain format.
# ![image.png](attachment:image.png)

# %%
# Example of string to time

date_string = "21 June, 2018"

print("date_string =", date_string)
print("type of date_string =", type(date_string))

date_object = datetime.strptime(date_string, "%d %B, %Y")

print("date_object =", date_object)
print("type of date_object =", type(date_object))
# Out:
# date_string = 21 June, 2018
# type of date_string = <class 'str'>
# date_object = 2018-06-21 00:00:00
# type of date_object = <class 'datetime.datetime'>

# %%
from datetime import datetime

dt_string = "12/11/2018 09:15:32"

# Date in the format dd/mm/yyyy
dt_object1 = datetime.strptime(dt_string, "%d/%m/%Y %H:%M:%S")
print("dt_object1 =", dt_object1)

# Date in the format mm/dd/yyyy.
dt_object2 = datetime.strptime(dt_string, "%m/%d/%Y %H:%M:%S")
print("dt_object2 =", dt_object2)
# Out:
# dt_object1 = 2018-11-12 09:15:32
# dt_object2 = 2018-12-11 09:15:32

# %% [markdown]
# ## Calculating Age

# %%
# Calculating age Method 1
from datetime import date 
  
def calculateAge(birthDate): 
    today = date.today() 
    age = today.year - birthDate.year - ((today.month, today.day) <  (birthDate.month, birthDate.day)) 
  
    return age 
      
# Driver code  
print(calculateAge(date(1997, 2, 3)), "years")
# Out:
# 23 years

# %%
# Calculating age Method 2

from datetime import datetime, date

print("Your date of birth (dd mm yyyy)")
date_of_birth = datetime.strptime(input("--->"), "%d %m %Y")

def calculate_age(born):
    today = date.today()
    return today.year - born.year - ((today.month, today.day) < (born.month, born.day))

age = calculate_age(date_of_birth)

print(age)
# Out:
# Your date of birth (dd mm yyyy)
# --->04 06 1979
# 41

# %% [markdown]
# ## Time Deltas
# Get time differences works for days, seconds, microsecconds)

# %%
tdelta = datetime.timedelta(days=7)
print (tday+tdelta)
print (tday -tdelta)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-44b1d6a3afd7> in <module>
# ----> 1 tdelta = timedelta(days=7)
#       2 print (tday+tdelta)
#       3 print (tday -tdelta)
#
# NameError: name 'timedelta' is not defined

# %%
bday = datetime.date(1975,11,4)
delta =  tday - bday
howOld= (delta.days)/365

print(delta.days)
print(howOld)
